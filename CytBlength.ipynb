# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
file_name_string = (r'C:\Users\mcveigh\Documents\PythonPC\data_table.tsv')
table_df = pd.read_csv(file_name_string,
                        sep='\t',
                        index_col=None,
                        low_memory=False,
                        usecols=[0,1,2,3,5,6,7,10,12,13,14,15,16,17])
table_df
# Out:
#       gene_id gene_symbol                 description  \
# 0     1267424        CYTB                cytochrome b
# 1      140512      mt-cyb                cytochrome b
# 2    16695886        CYTB                cytochrome b
# 3       17711     mt-Cytb                cytochrome b
# 4    19893556        CYTB  mitochondrial Cytochrome b
# 5     2565702        CYTB                cytochrome b
# 6       26192     mt-Cytb                cytochrome b
# 7     2642080        CYTB                cytochrome b
# 8     2652727        CYTB                cytochrome b
# 9     2657775        cytb             apocytochrome b
# 10    2657775        cytb             apocytochrome b
# 11    2846664        CYTB                cytochrome b
# 12    2866166        CYTB                cytochrome b
# 13    2866235        CYTB                cytochrome b
# 14    2885974        CYTB                cytochrome b
# 15    2947589        CYTB                cytochrome b
# ...

# %%
table_df['protein_length'] = pd.to_numeric(table_df['protein_length'])
stats=table_df['protein_length']
mean = stats.mean()
mean
# Out:
# 376.74257425742576

# %%
stddeviation = stats.std()
stddeviation
# Out:
# 19.951267360920482

# %%
tooshort = table_df.loc[table_df['protein_length'] < 300 ]
tooshort
# Out:
#     gene_id gene_symbol                          description  \
# 10  2657775        cytb                      apocytochrome b
# 46  5759861     cyt2BA1  type-2BAa cytolytic delta-endotoxin
#
#                                scientific_name  tax_id  \
# 10                        Candida parapsilosis    5480
# 46  Bacillus thuringiensis serovar israelensis    1430
#
#               genomic_range orientation transcript_accession  \
# 10    NC_005253.2:4243-8027           -          NC_005253.2
# 46  NC_010076.1:30321-31112           -          NC_010076.1
#
#     transcript_length transcript_cds_coords protein_accession isoform_name  \
# 10                247                   NaN       NP_943633.1          NaN
# 46                263                   NaN    YP_001573789.1          NaN
#
#     protein_length                                       protein_name
# 10             247  putative RNA maturase, partial (mitochondrion)...
# ...

# %%
toolong = table_df.loc[table_df['protein_length'] > 400 ]
toolong
# Out:
#     gene_id gene_symbol            description          scientific_name  \
# 30    35008    Cyt-b5-r  Cytochrome b5-related  Drosophila melanogaster
# 31    35008    Cyt-b5-r  Cytochrome b5-related  Drosophila melanogaster
#
#     tax_id                  genomic_range orientation transcript_accession  \
# 30    7227  NT_033779.5:16788774-16790721           -       NM_001273585.1
# 31    7227  NT_033779.5:16788774-16790721           -          NM_057806.5
#
#     transcript_length   transcript_cds_coords protein_accession  \
# 30               1557  NM_001273585.1:90-1400    NP_001260514.1
# 31               1465     NM_057806.5:90-1400       NP_477154.1
#
#                            isoform_name  protein_length  \
# 30  isoform B [Drosophila melanogaster]             436
# 31  isoform A [Drosophila melanogaster]             436
#
#               protein_name
# 30  cytochrome b5-related,
# 31  cytochrome b5-related,

# %%
table_df.plot(kind='bar', y='protein_length', figsize=(9,6))
